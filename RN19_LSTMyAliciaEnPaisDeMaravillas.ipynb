# %% [markdown]
# <a href="https://colab.research.google.com/github/HilbertN/Redes_Neuronales/blob/main/RN19_LSTMyAliciaEnPaisDeMaravillas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive #Para montar su drive y que puedan leer los datos
drive.mount('/content/drive')
archivo_de_datos =

# %%
#De aquí pueden descargar el cuento de Alicia
https://drive.google.com/file/d/1LqzexePKAltYbXNXxHBCtPveYRRtrij1/view?usp=sharing
filename = "wonderland.txt"

# %%
import os
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras import utils

# %%
raw_text = open(filename).read()

# %%
raw_text

# %%
raw_text = raw_text.lower()

chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))

n_chars = len(raw_text)
n_vocab = len(chars)
print ("Total Characters: ", n_chars)
print ("Total Vocab: ", n_vocab)

seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print( "Total Patterns: ", n_patterns)

#[samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))

X = X / float(n_vocab)

y = utils.to_categorical(dataY)
# Out:
# Total Characters:  83993
# Total Vocab:  70
# Total Patterns:  83893

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

# Para cargar el archivo pasado:
filename="weights-improvement-02-3.4902.hdf5"
model.load_weights(filename)  #comentar si se comienza desde cero.

# %%
callbacks_list = [checkpoint]

model.fit(X, y, epochs=10, batch_size=128, callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 656/656 [==============================] - ETA: 0s - loss: 3.2362
# Epoch 1: loss improved from inf to 3.23623, saving model to weights-improvement-01-3.2362.hdf5
# 656/656 [==============================] - 443s 672ms/step - loss: 3.2362
# Epoch 2/10
# 656/656 [==============================] - ETA: 0s - loss: 3.0087
# Epoch 2: loss improved from 3.23623 to 3.00874, saving model to weights-improvement-02-3.0087.hdf5
# 656/656 [==============================] - 437s 666ms/step - loss: 3.0087
# Epoch 3/10
# 656/656 [==============================] - ETA: 0s - loss: 2.8146
# Epoch 3: loss improved from 3.00874 to 2.81465, saving model to weights-improvement-03-2.8146.hdf5
# 656/656 [==============================] - 438s 667ms/step - loss: 2.8146
# Epoch 4/10
# 656/656 [==============================] - ETA: 0s - loss: 2.6636
# Epoch 4: loss improved from 2.81465 to 2.66361, saving model to weights-improvement-04-2.6636.hdf5
# 656/656 [==============================] - 437s 667ms/step - loss: 2.6636
# Epoch 5/10
# 656/656 [==============================] - ETA: 0s - loss: 2.5408
# Epoch 5: loss improved from 2.66361 to 2.54083, saving model to weights-improvement-05-2.5408.hdf5
# 656/656 [==============================] - 438s 668ms/step - loss: 2.5408
# Epoch 6/10
# 656/656 [==============================] - ETA: 0s - loss: 2.4299
# Epoch 6: loss improved from 2.54083 to 2.42995, saving model to weights-improvement-06-2.4299.hdf5
# 656/656 [==============================] - 438s 668ms/step - loss: 2.4299
# Epoch 7/10
# 656/656 [==============================] - ETA: 0s - loss: 2.3332
# Epoch 7: loss improved from 2.42995 to 2.33324, saving model to weights-improvement-07-2.3332.hdf5
# 656/656 [==============================] - 437s 666ms/step - loss: 2.3332
# Epoch 8/10
# 656/656 [==============================] - ETA: 0s - loss: 2.2520
# Epoch 8: loss improved from 2.33324 to 2.25198, saving model to weights-improvement-08-2.2520.hdf5
# 656/656 [==============================] - 439s 670ms/step - loss: 2.2520
# Epoch 9/10
# 656/656 [==============================] - ETA: 0s - loss: 2.1788
# Epoch 9: loss improved from 2.25198 to 2.17880, saving model to weights-improvement-09-2.1788.hdf5
# 656/656 [==============================] - 439s 669ms/step - loss: 2.1788
# Epoch 10/10
#  30/656 [>.............................] - ETA: 6:53 - loss: 2.1078
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-d98a6bc7b9d4> in <cell line: 3>()
#       1 callbacks_list = [checkpoint]
#       2
# ----> 3 model.fit(X, y, epochs=10, batch_size=128, callbacks=callbacks_list)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1787                             logs = tmp_logs
#    1788                             end_step = step + data_handler.step_increment
# -> 1789                             callbacks.on_train_batch_end(end_step, logs)
#    1790                             if self.stop_training:
#    1791                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1168             # Only block async when verbose = 1.
#    1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#    1172     def _finalize_progbar(self, logs, counter):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/generic_utils.py in update(self, current, values, finalize)
#     276                 info += f" - {k}:"
#     277                 if isinstance(self._values[k], list):
# --> 278                     avg = np.mean(
#     279                         self._values[k][0] / max(1, self._values[k][1])
#     280                     )
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in mean(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3430             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3431
# -> 3432     return _methods._mean(a, axis=axis, dtype=dtype,
#    3433                           out=out, **kwargs)
#    3434
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     166     is_float16_result = False
#     167
# --> 168     rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     169     if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     170         warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis, keepdims, where)
#      69         # no boolean mask given, calculate items according to axis
#      70         if axis is None:
# ---> 71             axis = tuple(range(arr.ndim))
#      72         elif not isinstance(axis, tuple):
#      73             axis = (axis,)
#
# KeyboardInterrupt:

# %%
Result=numpy.argmax(model.predict(X), axis=-1)
# Out:
# 2622/2622 [==============================] - 243s 92ms/step

# %%
for i in Result:
	print(chr(chars[i]), end="")
# Out:
# nor><rntentp""tttdt..ggrdeteo  oolle.tom/tt t- rlsrlrrrlrjoa><atte gullf oottridict:'robtttottont-goll,:/onmttttonttdodght:400;srpygrilg/gonss:gtogle..com/sorolloe//om/qioeen"uus"2rnfae""un"etttratarmttt'rrmttype"""t@punt-face{ oottgaoict:'0obttt'ttont-goll,::ontettfont-woight:000;;rstgoitgofonts.gtogle..com/sorolloe//om/qioeen"uus"2rnfaeueearafggr=e>onltttprrmtttpe"""t@punt-face{ oottraoict:'0obttt'ttont-goll,::onttttfont-roight:000;;rstgoitgofonts.gtogle..com/sorolloe//om/qioeen"uus"2rnfae"xecfar""anprtt'torettpe"""t@tunt-face{ oottgaoict:'0obtttotaont-goll,::onttttfont-reight:000;;rstgoitgofocts.gtogle..com/sorolloe//om/qioeen"uus"2rnfae"xttrraftr=e>onatttptrmtttpe"""t@punt-face{ oottraoict:'0obttt'ttott-goll,::ontettfont-roight:000;;rstgoitgofocts.gtogle..com/sorolloe//om/qioeen"uus"2rnfaeuee"turttrpe>bnltttptrmttype"""t@p,ontotcorae >ooecttrn"ct--o0>rntettpe"tttsns'oditeen olleaor""">ore_"gonlee""omtetstomtetgoogoe>oolenype"fttset  n oontettp""tmsettt""">oye_"dete >oolo=tpe=tttscte f"onteet=""tttse"p"odole >ooleetpe""ttsct  nott >"rntettp""ttts  googegabet  qoolo=tpe=tttscte>gonteetp""ttps://drive.google.com/,ilee//1lqzexepkaltybxnxxxbctpverrrtrij1/viewuuup%"dplegmg0rapkipi,dhpwhgttttttrr><aepe grll,"t_len"tr"raee>"unl,""ttps://drw.ggtgli..com/s/lgee//odese//r3roeoipu03rmrzteeq0000r03009.gbel,"drlsu0rll,"tll,nupettg"unl,n"rtps://doive.google.cogecome,"llliclble//ogeeggrmihg30,00000,,,0,0,0,nll,nu0rlse" pl"r"sr"rrxxxbaa0cartu grll="tnlenupettg"unl,n"ttps://dow.ggtgli..com/s/docs-eull,e.ecbodol"onmpe-forefrygrgodidkottfo0rbqaqrgazdqqqbrzooq220rp> gupu"oag3dhoogoreoeyr""o""unl,t"trmret pl"""rr"rr""""aa>ratt  n "oolo="trntttr-ror"oioddortgod>ohttpoprogottttt"tttttr>ogodaugttal,gbott-ridd":""ocs-eid"":"",csspspl,"docs-esd":"",tss:sdel"","docs-er":"":",""ocs-esd:","docs-esd"":","0ocs-esd"":",,,s,"docs-er""":",""ocs-esd"":",,,s,"docs-es"":","docs-esl":",,0ocs-erl":",,0ocs-erl"":",,"ocs-erl":",,"docs-esd"":faue,"docs-eess""":faue"ocs-es""""":false,"docs-eesd"""":false,"docs-eesd""":false,"docs-eesd""""":false,"docs-eesd""":false,"docs-eesd""":false,"docs-eesd""":false,"docs-eesd"":false,"docs-eesd""":faue,"docs-eesd""":faue,"docs-eesd""":false,"docs-eesd""":faue,"docs-eesd""":false,"docs-eesd"":false,"docs-eesd"""":false,"docs-eesd""":false,"docs-eesd"""":false,"docs-eesd""":false,"docs-eesd""":false,"docs-eesd":false,"docs-eesd""":false,"docs-eesd"""":faue,"docs-eesd":false,"docs-ees"""":false,"docs-eesd""":faue,"docs-ees"""":false,"docs-eess:"""":false,"docs-eesd"":false,"docs-eess:""""":false,"docs-ees""":false,"docs-ees"""":faue,"docs-ees""":false,"docs-ees""":faue,"docs-ees"""":faue,"docs-eesd""":false,"docs-ees""""":false,"docs-ees""":false,"docs-ees""":faue,"docs-ess"""":false,"docs-ees"""":false,"docs-eesd":faue,"docs-ess"""":false,"docs-ees""""":false,"docs-ees""""":false,"docs-ees"""":false,"docs-ees":false,"docs-ess":false,"docs-eesd"""":false,"docss"r"""ooso:t"eee"e":""t","docs-esd"""""":f",tps://drw.g.ogle..com/,"lseeodlle""oml,e""","ml,"docs-er""""":false,"docs-eesd":false,"docs-ees":false,"docs-ees":faus"dd,60,6522292,22666,,,198,,449,296,7,,72666,,,772266,,,0972266,,,97266,,,594266,,,4942264,,,97266,,,4972268,,2972264,,,972668,,497266,,,4992668,,2972666,,498266,,,4972266,,,9422448,,941266,,,94266,,,074666,,772666,,,942666,,,942268,,4942266,,,941666,,,972666,,,972668,,4972264,,,772668,,4972668,,941866,,,948264,,,72666,,,941266,,,941266,,,721666,,,97266,,,072666,,,972666,,,4984,,,097226,,,741868,,5972668,,209,248,,74266,,,941268,,,047266,,,941884,,,97266,,,072666,,,47966,,,941966,,,942268,,4041266,,,741266,,,941268,,4072268,,772666,,,972666,,,77266,,,4972668,,4992666,,,992668,,749266,,,741268,,5972666,,,92866,,,297,208,,4097268,,,041266,,,941664,,,942268,,2942226,,,941266,,,772668,,772666,,,972266,,,9772668,,972666,,,2968,,,4942668,,972666,,,2994,,,,99266,,,972666,,,92666,,4972266,,,941866,,,92666,,,4972208,,2972264,,,7266,,,4972268,,741266,,,77266,,,2992244,,,972666,,,972266,,,97266,,,072666,,,992668,,749866,,,7266 ...
# fb.a.=a(g)b,)).b.)a)())))et.bb_.=function(a{rer b=_..c0._.aa)()))))).turn a};_.=function(a,{,{)f,c.da{(a))))rr.ba..))).)..=tunction(a,b,{)f,c.da{(a))))er.ba=...))|)urfunction(a,bre(cuu0a0;a.0)|lurn a};a..aa09)009))))|boefunction(a,{return a.i o=a&b&(0=_uct"===yypeof a&&a".rcti"rotetn(a){){r&a(etrceeoro==b.(urn.ic.bb=function(a,{re(!.i){risrn .roo(";`._.nfunction(a,{){rfr{a{ala(n];e(u.h(s.0;====.a.+a(ghh).(],)))_.c(=function(a{ret b=_.ncoic;aa(aaa)=rr ent:===.cc=aa&a_.pe=function(a{ret b=_.ncoic;aa(aaa)arurn e)==tturn a.r_.=a=function(a,{re(u fui=otot((e)){rar .(f,b.purn a.r_.b=a=function(a,{re(!.|rl=="===typeof a&&aturn".aa;t,;.(cni.a==tuee.e)){btr .(f,b.purn a.;_.=a=function(a,{re(!.rl====&c==reo="===typeof a&&aturn"rroo(";}a(urn a}r_.=b=function(a,{return _.isn=.?nct.rcoi"===yypeof a&&.teis 0;=_.sa=function(a,{,{){ve(!all===|&c==ruct.)==typeof a&&a."a(a.n((.uitrn a};a(a)aatiorototn(a)))arr d==0,_."a)()))))t.n],f).&,).rc ====..(c.===|&(..(())a.)()())))))eturn a.is_.faf,(_.er=function(a,b,{)er .aa(un t._nf,bru.i( 0}=.iurn a.r_.b=a=unction(a,{,{){vers ===&(=.a.rsau_..n( 0}=.y".rl===)&r=t f==.0..a.==..(]=rc.b====(.]]]&&&=aa2a2),&1))|bb2(2,)&)&&12<aurn ded,=nttiorototn(a)))rarr "rrar(";}a"a,_."a)(a))))(a))))).(urn a}}a(a)bncte")=a.&a(sc==.nc.===(a&&,)=rr"ba"|"())(])))|rsr ".rar(";})&a(s.nb(ug==.n](gth;1+(]){rar d==.0],.(.n]ng](g)ig)&)erur e..=(]0)).a12)))))|(]k]]],,)&&&&&2),aa2,2,),))&2)))))(]&&,),222)|gb2,2,)&)&&1))(asd0==ba=d&==&&__.&,2))))))).t rnal(g)0,(,),)&&&&|&(&&.a(2)))e_.|(a.x=0(=.0)))1))s2a2,,22))|bb2(2,)&)&&12|(g&_.aa)()))))&,eturn a};_.b=.nction(a,{){){re((var d==.0,...).).nength-1)a])])];]+)fbrr d==.c];c.(lt==|&c=f,b&&&))i.=eng]),as.ntth;c++)f.(]]]]|c.efunction(a,{){rer rn a.a:a=aa.nfunction(a,{rets rna(ieof.&==rtscc"abnctio===turn a}ictio"")={t=yepeof a)&a.terngoncti"")=tturn a}r:aaaa(urn"oj.ct""=tt".nd&.oitirrototn(a){)rarda&a)&,))brurn a.}a(_ra,.("&|nction"===ypeof a?&btaaa"a=trnceof _.nenaarurn a.}a(a).rro rn "};_.b=function(a,{){){ver d=a.cd(a)a))t.lentth)))a])))fbb(]+]=bb(u 0;==&c=(]b))b)((var.=(b,b&))))&]l]+],=a]e]]&,b](],b(&)&,=a.n](]e(c.e(tar d 0n _)&) ](]]c))](],(s!.")),erurn a.;_.=function(a,{,{){){){){re(!all===|&b=t"anctiorototn(a)))va.&a=aab&a(eth)))==a.ca)))))))=.is 0;==&(==a."a)()))))=.(ang))){,d,er d,&)..&(),),et(rdd(],=_,b)err d=a..b.i.=at.in t)&)(]n].n]&=](],)){,),),))et]nctlo0;a.&(a,&,eturn a.;at.b(function(a,{,{){){){){rer d=a.ncy.f===faa(a))));.(.n],==_))))|is 0;==((var d=0.0,(g.b,)t.b.(.nength;c++){vf.c].(],a](],b,{,a,))))e&)).i&.))),)t,d))))eiurn a.;_.=function(a,{return _.aa(tunc(uuna=tonne,}..caaa_.b=function(a,{,{){ie(urs 0===..(a(a.n](g,il===&&b(t!ar))|_c=ernceof _.leeganay.protrntf}a.cenura(eefarctipr{r=nc.rctiorototn(a){)rrr d==0,=."a)()))))(c.)))erurn a};a((a.aa))).(cvab._a))&&)))i))|({.|",)))))|iurn a};](<a.2()(a,)))ec&b=)-"))),)(a)))),,),)e(u.l))&&&&1)).is.((),((.,bb"]]e,,,,)))&.)()))))t.&)ee(]]e(g)b,((trn e.ro=._b=f,b))))).)..isrn a};_y.rb=function(a,{,{){ver d=a.(cy=b=.(aunf.i))_=&b))).(](])+){,ern on(a){return a.a:.aa&,a,_.b(a.&a)().)))e_.s(.,))).iurn a};_.b=a=function(a,{ret b=_.0,();),).fb)())))eturn a.}a.a&a(a.ba((trnee.ro=.;b=f,b)))))...(c.eb=function(a,{,{){){){ver d=a.l],i)btc.l))(ct.b(funb=f=a,&&&=(.n]+](cth-1][+.(er prcallo=..&a=urn a.ran]n],___.aa))))))))|=b.ec.bb==bun]]=]+,b[&&,&&.&a)(a,),)als  g.c](),&__.a1))))))))(&a1,),&&&=aal]]]((th-1+))(a,ag)&))turn 1.a](],a.c(=function(a,b,{)eturn a.ilo=a?a:=bnc..=function(a,{,{){rer d=a.cd(atrneeoro=.=f.nb(f,bb.fb)aa.).)b=en,b.(&)).(a)))(rc)|_e)u.nb=f.a,|iur==.lf,i))e(h;1;.(])a]n]+b(gth-1+)&)a(e!arab=(.nength;c++){vig&i](]])fb(r f od=erante))]&a(eth-1[a+.ib.aa=((teoct0}=_..na=]==.(],).fa)())))))e(e(g,i,e(]d)).i)))))))|((var d=0[a,,],|(.nength;c++){vag&i]n];g,i]),(g)|(al r==un];f.nl==..(.n];f]n]+b(g.n],b.&&=f,b[&b(g))(g))eeschg.rc!.r r  0}=.f.nt(h)1)=(]ba.n]ne(gth;1+));a(an]ne=tt=,r];g.b.(un]nf,nl==.)r.n]on]n];(]+b(g.ng&b=&&=_,b[&e(g&|(g))els.0(=eth;1+++)=faaurn a};].asg=".nf,i_)a])]]]=&)=rs.it 0==.n]na;t.rf==.(cvar d=_n _.i)ne(urf= ...
# .b=b=function(a,{rei b=_.batof""=====tpeof a?ntolo&)|rcol.&)otot.ri!a.neteof.aeetoter ra.nc.beturn a.;a(et)ab).n"&.ne=a""==ypeof a&&aturn"a.rurn eeternals)bbtur rn".roo(";`n&aarin "a={&=rp.cffunction"==typeof a?ntct.ieeite)eenuet.georuentenction(a,{ret b=a.nction(a{ter.pr=totype.tofunurn t.is_.(c.b="fbnction"==typeof a?ntct.ieturt epeee"e(",nfenu.t.greurn eeeer"e("oncteonta)ofeneis 0==funs.;._.jfunt.rsor t.nftttpe.ootuung.ngba.((tef;=_.ecte){r.rsc0==_.cf=function(a,{){rfa..c(ticetr.funf.b,)((ticeti==y&c=ern"rr r=(eerrone",;n&cb&bb(urn a}r_.=coe"te)nc..a.=unction(a,{){rfa.llo=ype=t==fr=dotorype.b==fdototype.b==ttrn=eo===.n.nf,b_.,)b)b&b.(crabrctar c=0n t.i)(f).reoe"peef;;tpa=t.otct.pe=tnettoptttyn(e)rir b={enuen.feeentecpeettrnccectrirn("}{b{)a&b.ruct.)=ttcetcpertyrer,b){){rarcn .r](]hn](].&==.ne=totype.t=.b=f.bneot"p)=ttption(a){re(ction(a){)hii .h=a.itotoeeeoioet({){rai rn a.iatttnceof _.nenenur.a.nction(a){retaia_rrsc=)e(urn a.;.(entotype.f==unction(a,{ret!uil===|is.i={htts.i=n];hhisg==.is.i.ns.i={hsttion())rat.i)er.rt t))aesttt.)es.r dd=unfuntotteert_.r.=totype.ia=unction(a){rht.aa)|i.pe=totype.b==unction(a{re((taris.i={)his.iath;thh;h+.is.f=n.is.i=this.h=n];hhiitar d=;.;=t.nength;)+).fair d==.l];c.(](][(ct=.i o( }.is.h(e){_.ts.h=n;}};tr dea=nunctio.ae=totype.ia=unction(a){retu.h=_)ttthon(a)rttorngea)hi.ser cd=unction(a,{rets.h=_.hhis.h=thit.h(=.is.h=th}hhis.i==g;=his.=t.is.i=t;hhisr  .rest(t)e)h{ett.h))eis.h()){r._.nsot.p){ror prototype.ba=unction(a{re((tion b){){ret rn a.iction()={retrnai],b.t.se(h,i)})hrs! r==eis.f=n];h.isrn eeter(("te)resegaa)hrsc .arte=tutaieot.pr=totype.ta=unction(a){retcai)hhis.h=nththihstt.is= .in "}}{}f.o(cvaar&a&ettrnceof _.gettcnaa)})hictionoitotyt)itot(&){rtsch"abn.ct."=truc=nunctf.;n.nctio==.nec&a.nction"===t&d=.|ctia==.ycueotlet)=ar..is a={r{,his.h=_;};a_.zdototype.b==function(a){retur=t.is.f;=.isrn .aessht(tectt){retu.ha))}}hisrn eg};ction()){ypeof a&n.is.ta{){)})his.h=a;}hi.pdototype.b==unction(a){retu.h={)};};_.pdototype.b=function(a){rets.h=_)};};_.pdototype.b=function(a){){vet!.&)ris.d=a;tsrng.ooo(";`n&;as;.a;.").").is.))a);is.i=t];his.h=nht]hhhhis.h={;;is.i=tg;hhis.i={;;_.pd=totype.b==function(a{retub=_.is.i.thnttion(){re(c.i){)dhis d==.is.nctiype};_tot.e)t!==typeof a&&a.tantt(";a)};r_.}._.pr=totype.b=function(a{ret!uis h=}hisrn a};.isr==uis.nctiypeote).n]has.ncten=oews.nttttps.tonla.tg,urs eue"t"==typeof a&&eturn a}a).rction"===yypeof a&&.nenur=",.rr! "n"ttttttt"t(",rruch(eate:t0}r).bb=ction"===yypeof a&&.nenur="..rs" "n"ttttttt"n(",rruch(eate:t0}r).bb=urfancyentogrerteoteat(").nctineeote";"ttattnntpe tyort(",ois"e"""t""t"tt"t"""",".."."b_."ento(ee"ontetane=tu(tt.rs.t=nhtu.n g};h}h_.pdototype.b==unction(a{ret!.il===ris.i={etsrnaisw=;.hht.is.g={hnhhh;h];.dhsh))is.h)i];h,his.h=n];ttton.r f=n.nu_.n.nentotype.h==unction()){retub=t.is.i=t}hhthsghi);srn e)};t.ss.t.)et.neototype.ba=unction(a){){rei d=a.is.f=t}hhisrd .rst).ieseisrn e).nest,t,)e=uchte){r._.ntct.pe{ro_ pr=totype.ba=fufunction(),{){rer(tion a({){r{ret rn a.rction()=typeof a?t.nction(a){retorycures}his.h(e){_._.j);t.ri  a=f.se,ur ed,dnttion(a){r{ret r turc;;is.h=ng.})})})hid}e})hhisrn a.i_.r.=totype.f=fufufunction(a,{return _.is.i.nt}t.is.g,t.ths.pdototype.b==function(a){){rfr(tion a({)hird rnt){r{rasch),r.&eseg)htctio)oeit,b.&eseg)etct.o)ogce;otei rnd.ror(";`n&;ba.s)eir  a==.n .t.ngoi);is.h=nghhhths)his.h=a;;ttt.i)his.h=;];hi.pd=tot.es.n.fe=tch,;enction(a,{)eturn a.i _.(.nttion(a){){ret.&))ra.ce=fch.nction(a,{return a.is_.(.nttion(a){){ra((var d=n.ne=f,,,.r.pe=to);..._.nctie).nent(t,k.p.)e,urh,,.(g.i))eg.r.nd=ftunction(a){retub=_.ce(s.a).t.ne=t();..(urn a};antth));=]c.(ur=0[nttion(a){r{ra((tion(b){r{ret rn a.rction()={returntn.pf=b.=.&a.a.grer! r==]n0b(.c=(c.i.ntt=ers,0,=,._.d.ae))eurn)).(a.i)g)et(h))))).i).a.ne=t())..( .n!)=).s(t)))rs.n en f};_.bb=uc==function(a,{,{){ver!ail===)&attrn rr r=(eerrone",rn.cb"a=(c.))(trnceof _.ls,t()ar rt".r r==torron(",;n.cb&be(urn a};a";_.rfabreer"==ntotype.ta=_ueeefu=fuunction(a){return a.i:functi ...
# ab("ar("ab("or."r=unuetntt(ee"ee""unction(a{return a}a}"0a0000000990egb2b=")|n"oce"=otutyee))rnction(a){return a.a:function(a,{return a.i oi.&==typeof a&&&aaa.(loi"=&&=.rioi""e===a&a".is=""ee===aeavar("abnboi""rototyee)),unction(a){return a.a:function(a,{return a.isni.==otuen.e)){bata.e(urnaootec;&;};ais..r c==function(a,{){rf0.aionceet !.ieog."===t.a;"aoisc=".0._.,)."ers rn ootion(a{re(!.=))=t.nentth)))ir f==.c],.aurn eeter:te0r{ree(],bncti&}.tt.0&=.turn eetr &0,0rtue:teit 0}=teo.ra=eof arototnr ra.nction(a{return t.i_.r rn a};_.b=""bncyiprototype.filleenuffunction(a){return a.a:function(a{return a.ishis,fanction(a){){rer rn a.0(luru=_.r("ubncyiprotot,rnction(a){return a.a:function(a,{){){re(.ilo==aab(anction(a){return a?ic.r f==.nc.=.b=ro=te"t"==tpeof a?ntolo&)|rbolo&)otot.ri!aeneteol.aeetoter ra.nc,bnction"===ypeof a&&etscca=l(t,i,.tcvar d=a.b==.t.nengt),b..(cta))).net=u)))](c,i[),aurn!e))d,.is.n!.rotar.=e=gth;)=a])=(]n]+)g=a.nt(=a)))](c,i,)](],c,).rurn a};a
# .bb(f)bncyiprototype.filee".bnction(a){return a.a:function(a{return a.isuis,fanction(a){return a.r_.(_.r("ub("oi."rotot"==nction(a){return a.a:function(a,{return a.isni.&==yypeof a&&aarcti"=&rtr.u("arncy.prototype.filueeuffbnction(a){return a.a:function(a{return a.ishis,fanction(a){){rer rn a.r_.=_.bb=furrcyiorototype.fill",kbnction(a){return a.a:function(a,{){){rer d=a.is.f=aath;.rg.b.a&ac.i.=urnarer)b.).)))e(&.il==))|ay.ear=enena(coi.a){ra..&(&.i.iurnar(r),._.),)e((!ar.(tof.a=era.b.(.n]ng=.ru.iaea.f.n rn a.is.re_}r( e==function(a,{return a.a:functiorototype.fill"efulfubnctarctiorototype.fill",kb)f)b("knnee"aratiprototype.fill",kb)f)b("knnee"aratenteernudrototype.fill",kb)fxb("kbnetarrcyiprototype.fill",kb)fxb("kbnee"arrcyiorototype.fill",kb)f)b("knnctarrcyiorototype.fill",kb)f)bb(""r(te"arrayiorototype.fill",kb)f)b("kbncti"==rpyiprototype.fill",kb)f)b("knncti"==rpyiprototype.fill",kb)f)b("knnect.)r=ttttoc)unction(a){return a.a:function(a,{ret b=a..0b(.(ctarn t)b)(],))))).te(t(g)r]b=.(]]==(urn a};a
# .r( e==fu,f.,f.nb=fun(=ern c.pa=ur .neeeurs.ns.nb=.n(unntt:(rn_.r.fb=function(a,{){rfr.]all=t"=&&=a.(a|(t.b(.nctar d=aab=(.l]ngth;c++){vig&b[(]]]]]]b(l==c)&a=urn a};lt=.r rn a};_.=b=function(a,{ret b=_.ieof a&&.iurn a.isct.d=t.n.nener(t prototn(a))){)rit o==r0b(eo==".pa=function(a,{rei b=_.ieof a&&.iurn a.is.t.i=ty&d.rlo==&|ay.rction"===yyp.pr=fuunctrneeoro.a===.taa)ernar rt())=..00).is.nction(a,{){){rer rn a.aa(at)unctic.aa;(t)arctentootar.b=function(a,{,{){ve(!a=)aturn"rroo(";;a(")aa((trntoosanott;)rrr.f==.nctiorototype.file".full(a,b_yenteot;b..turn a}rction(){tet f==.nctiorototype.file".cull(a,b_yenteot;nnctiprototype.filee..ucfnltt),,)})erurn a.;a(etrc.a)};rrr rn a};ction(){teturn a.aa(etrf.a);atrntootarl.bb=fnction(a,{){){rfacca(ction(a)itorype.fall",ubbb.)(ction"==ttotype.fill",ullenyee);;tncoiont)rt.rn a}ntt"=b.b.untunurn _.;asa(atr".roo=.rayentootai.bbb=.nction(a){){rfr.&all=("=&)=a.isb==.le(.n],=(_)ratar "i"""""==ypeof a?&bnctionetetyec?cctlooileaaeruc==.n]b)ce(cvar d=0.length=),..d.+e(gth))))a.c))((h;ert f 0)=t..pen]n&;==.=],=e(u.n.deetotype.ienu.n.n]nc.=.(]n]e(d.a.=]b(c.===fnction(a,{){re((tion a({)har .rlotype.t==r=totype.t==u=fnd.totype.t.f.=totype.h.=ff.n.nd=totype.b==_trn=eor==.nfne=function(a,{){){ver(var d=a.nctiorototntootanctt;c+)).i.b=(.nctenteot.ngth;c++){va.c)bb]n(trntooter)rnurn c.}a(ttrype.t=nf.notifr,)}err.jd=f=d._.otot"eraa=prototype.t==f.fubnctineeooo_;;ta(s.ntot(p)ototype.filt",unction(a,{return a.aa(tofau).nction(a,{return a.r::fur.bbb==.(ued;=.=|(ur ;"c==.(ct=)&;=;er.===function(a,{,{return a.==.(a(et(on)))aaur c==fu,=.nuu="==.)).iur==func.ig)b)c=.&((s.is.iction(a)=_una(f,|rtr errte:r"tr"erctar),bb_.cn"ab="c0==011199).lkolct=,b_.entc0b_t d=aaa;fo;sc==fb,fuq(=.nurt,o;t_.ra.=s.is.il rne:rnttatrn e "enro0.)e=uunctiorototype.fill"nctfunction(a,{){return a.rat.prototype.fill"ectfunl(a,b,)))r 0,)._.nction(a,{){re(!&|rl=="===typeof a&&aturn a.rsr(""==typeof a&|bt.b."a=eth)e+)..&a)eteo("))){..((var d=00b=(.length;c++){vig&&n t)&))t]n]]+e&b(urn a}a.(urn a};_.s(=functiorototype.fille=fufunction(a,{,{){vfr(t orototype.fille.fcfunl(a,b,,)));.rction(a,b,{){ve((var d=a.lentth,).)]bre= ")==typeof a&a.santo(")&)a."((aa)(.n]+){=fn t.&))a.ee(),i))],],c,),a.baa=a.nctiorototype.fille=ufunction(a,b,{){ver rn a.aay.prototype.filleeufunl(a,b,)))br.rction(a,{,{){ve((var d=a.lentth,).)]e+(f])=f]b=r= ")==typeof a&a.santo(")&)a."((aa)(.n]n){=rd))n t)&e(t f=a.n];a.(.=](g,i,),,,)))&.i]g).(.(els rn a};_.=f=funct.prototype.filefunction(a,{){){ver rn a.aat.prototype.filefunl(a,b,)))br.rction(a,{){){ve((var d=a.lentth,).)]n(tipr{d=a.b(e==")==typeof a&a.salto(")&)a."((aa)(.n]+){=_n t.&))eiui].ne=](),i,)]n],c,),)eiurn a};_.b=b=functiorototype.filfufununction(a,b,{){ver rn a.aay.prototype.fileufufunl(a,b,))))r.rction(a,b,{){ver d=a.c],_.ca)s.="a(ction(a){){ra(.nall(t.is 0,_.t.f,a)})_.e(urn a.;_.=f=funct.prototype.fileefunction(a,{,{)eturn a.aat.prototype.file".unl(a,b,)))r 0,)._.nction(a,{){re((var d=a.lentth,).a]=re= ")==typeof a&a.salto(")&)a."((aa)(.n]+){=rd)&n t)&))a.ee(),is 0,_.f.n],c)),eturn a};.(urn a};_.sa=function(a,{re(..taa==a.{,eiurn a.;_.=a=ffu_...(ction(a)ter r cd=funf.otund=fund(f)b.cb=.n((g)|.&b=_.n(_.bodc))_.p(=_.n((ern.b..fe(g.n(_..adct))___..a((_.)))))).is.   ese((,"_._sct(e)___.".".pa""))_____."(").or"))");|__.(".|r""")&___..."_."""))|.p((_.n((_ra)(_)).isr(" ete((,__._sct(a)___.".".pa""))|.pc(_.n((f)|.c((auns)|"c(tr "e"=a..p"urs rn e!b}a_.ror" eo";=."c(aunf)|_c.ctrn a)}..paors rnea!t0a__.acten"))=tycpauns)b."b(aun((.ro""))|.pc=_un(_.roe"))|.pc=_un((f)|.("unction(a{rer b=_.0e(.nctento)erurn a};.;b(atentoottycoit 0}b_.b=e=tof==fc,_._uunction(a{ret b=_.ce(a;).(".i)().rurn a.is..(.]b=&c)=aa).bb=(ctc));=(".)))))aurn a};ate]+=.aa]])))&=(lsd=&&=(c.))),(urn a.;a(=e(enf ne}aa==aa(&a)&;)="a)ab==(ct=)&;e(".i))))aurn a.is.n(e.b..c&b..(ct")&r.(".))))aaurn a}}a.(urn e)}}}a.)&,ea)b_.(cti)&r__..(""_|""ut"unt.b=."_..(".)))aer d==f.;s.=.(".llt=)|_"d|_"unuen e:teprr_.unt .(en e"r=_.unctio==tenfun r.b=funfunf.bb).nctente)).f.{aer d ...
# .b.b=unction(a,{,{)fr.calei rn a.aa(),a,,a.ca)().)))fat.pa=function(a,b,{){){ve(!a==bb.&alurn a.rlr=.ra==].(&.c)erud=&)))&b(urn a};a(a(lth")=a..(er .o(rn d==.0e(eth"n.n&.a,b&,d)&)).i.n]+]bb[(],(l===&&c=rurn a};a(a(),___.a)))))))))(s)b,)alern a}a](e;b.bb=function(a,b,{){ier d=a.0,a,;),).tb)()))))fa(a.)))&b(a.))),},))eturn a.;_.=a=fnction(a,{,{)f(.0ala{,{,erurn a.ilr=.?a.f0=rctr""===typeof a&&a"aiso""===typeof a&&eis.0;=&".oi"."a=function(a,{,{){){re(.]aler c=n],).fb)()))))t.ne(g,b,,,))))et.ne(g,b,))),)&)ee&)err==)|&(.f.(()))))},))))eturn a.;_.=a=fnction(a,{,{){){re(uis 0===..(0a=.(an]ne(),b,),))))eta.ll==)))cturn a}a.(a&a(er g==0,=.fb)()))))(a&))a)))eis d=a.0((g)a))&)ee&())i.g.g,a,,))))))))))ets rn a.;_.=a=fnction(a,{,{){veru f==&(==a.rt 0;==.iurn a}}a(auaa),)b_.p==fnction(a,{,{)eturn a.aa(_una(,a)}))_.p(=unction(a,{,{)eturn a.aa(_un((,a)}));;._..aa=function(a,b,{){ie(urs 0===.b(a==(a=]+a(eiub==0,).fb)()))))t.ne(g,b,,,))etur==.lcof.=(.=]=(l!="===yypeof a?|b_ar c=bb.(cv.r ti"""===typevar(fti""====typenc f.&={,ets 0;=.teof=&&aa_naa&a.aa(a.b)),f)f)eturn a.}a(a)a)})_.z(=unction(a,{,{)eturn a.aa(_un((,a)})));._.p(=unction(a,b,{){ve(!ull====&c=e"a|ncti"e)=ttypeof a&&aturn"rroo(";`n&aaaa(_.b,).";)"ae(]))rr( on a=}a(_.a)))}b_.pa=fnction(a,{,{){ver rn a.aa(_unaa,(ro=arr.f.=.())a)b_.ca=function(a,{,{){ver rn a.aa(_unaa,})__.))._.baa=unction(a,{,{){ver rn a.aa(_unaa,(ro=arr.f.=.())a)b_.ca=unction(a,{,{){veru.h=_.v(a)};};};_.z(=.nd..ototype.t.f._dototnpunction(a{re(!uis.isc=;.ishis,t)is.h={)}h.ht(taar.(]his.h));;ghis.0,=.is.0,=..a..a..".(shis,h,0,,_..iurn a};_.=a=f=function(a{retu.==.iern tro 0}nati.rs, "e"t"rrs.tals,t(")}.ttars. .edonyt}}rtd.rb=f=function(a{return _.aa.a."a)().rs.ha{)}_._.p(=a,_uns.n(=.otordeefunction(a{return _.ishis.tais.h,{)}t..is.n  a)};_.pe=funtoio))t.yc=..(tof())=.yc=a.ntol())=tyc=..ntol())=tyc.a.reo ()==tpup==function(a,{retu.h=_.v(a)};_.z(_.o_.,);).rd=function(a,{rets.h=_.v(a)};_.z(_.,d,_.r);).rd=fuototype.b==function(a){return t.a(_.ss.))h))e_.r cd=function(a,{rets.h=_.v(a)};_.z(_.o_.r);).r cd=function(a){rets.h=_.v(a)};_.z(_.o_.r);).rprototype.ba=function(a){return t.a((s.it.t)h).};_.pd=function(a,{rets.h=_.v(a)};_.z(_.,d,_.r);).rd=unction(a{retu.h=_thit.o=;ghis.h=nghis.h=nh;.;._.ototype.h==f.u..pd=.ototype.ba=_uneee==function(a{return this.i.ntt.;.=r=totype.ha=function(a{retu.h=thtthis.h=nhh;h.is.i=t)}h_.pd=.ototype.ha=unction(){ret!uis h=i)hittaris.i=nghitth.n+.is.i=nghis.h)==).i.r dd=function(a,{rf(.call(this.t;his.h=th}his.h=nh};his.h==hit;.z=_.s_.,);).rprototype.ba=f=eu=function(a){ret b=t.is.d=thth;hisot"=;.;..i(tar d=;.length,).)])=(]+])=&aag)))(];]]==](]]]]]]](etaa( rn a};;;=.r rn a}}aatrnceof _.nctione))neltoro.og)etotype.fa=function(a{re((tar d=a.is.h={;;thh;h.hhis.h={hthhhhthhht.n]==thir d==..];c=i,&=i.rs.g=a;hh(e)){)h(s.i))f,etu.n=a.;gh(e==durfb(_.ib(tch(e){_.rs.o!.p.=togar](]h(s ="=a.wenat.o)){retof&)))ei.r dd=function(a,{rf(.call(this.t;his.h=th}his.h=nhts.h=ihittthis.h=n]hhis.i==eig.is.h=n];h.hhis. .b=oggttoit!ers rnotrn]}).calcteon")rnco""&__..."a(eteon()ratof.o)====.".=="a)e(ctron"}aa(aaa(&a)&;)="a)abb=(ct=)&;)".""c))""e(urn a( egra]b);)).is.naa];_._.p(=.,_.,))).rarototype.b==fnction(a){){rets.h=_.v(is.h=n.}hihitotnpe.t:.on_.sb=totneeot:e(tc.bb&bturn eetri!0}r_.cb=function(a,{rets.h=_.v(a)};_.z(_.,d,_.r);).r cd=function(a,{rets.h=_.v(a)};_.z(_.o_.r);).r cd=function(a{retu.h=_.ithtp.tshitotype.oo=tuunction(a){rf(.i{ais.t)}h_.pd=function(a,{){ret!.i){rer d==.i r=na.ne(g,i,).m.(urn.hc;.fe(s.i,).t.(t .);=&ca,d)))&e(trh.es eg)b&aa,g,))&&.(.isr=0.((.;(a,b,)&&&&.(())lt!),))_.er r d==f.,_.,_.,f.nb=function(a,{reis.h=_.h_.pd=frototype.ba=trrn===unction(a{return this.i.thitri te)};_.pd=frototype.b==_.b_.pd=frototype.ba=function(a{return this.i.thisri te)};_.pd=function(a,{return _.a((trnceof _.ge(g..abnctrceeoro=.b.fb=funa(.boeo=rrotideostton".i.nfub=fu=n.b_...(-etgb=.0e=.b\."a),))&.ie=scb(,=0,).(loddcase(oolderg)b_.caa=b=ab).&a))e
# &__.(a|"a(eunction(a,{re(!.in trnceof _.go(a.rurn a.;a(abrurt"===ypeof a&&a.aa=aana())b.(eo  a)&;.tu.itrna_);a.&e(_)i,).c.it   a)&;arurn a))=,..rc.."a="."_..".+ee(()))=f..cb(_.)))terd..aurn a};_.= rn ta.;l_.b(.cb=ffb(a.)|)..h(e){r.rsd}|_.u=funt.ns.od.p==function(a,{return _.i _=b.(f.bb())r.ce=fund=fr.rcee"crorird!t=uc en e)==.iuc==funf.otunb=function(a,{rei b=_.is.  a.ogte.&)rr..t.google.&)ntettla}}".rloi"/wra.gaocle.com","r"bf,btue"""..(eof..tolrg)i.&a)&a(g)))&)))a(((h)))|(&.)b=g,b)(r e(fra.n unction(a,{rei b=_.i r=(a.i);a.is.ne=tttnpe.ra(eonceefentoe((etrction(){re(aaaarsdunctepd.os.n.i.r ont.==.(]].(g!.)b=f))b)ur cnc.(f.;."e=function(a{reru.h=_.vhhito._a=fuototype.t==function(a){retub=t.ccba.(ctarn t.is.h);h;s.i==tt=)rctentisti:((""tr"a",{.&bbncteneonteen(""er"arro "")nt.tanlatenfrf=.tsrn a};ntynu_e=t.bb.(uca=er"abneen ea==="""."ate(=,"_....is,((")"}"a).r cd=function(a,{,{)etu.h==.v.hid.r f==.0(=.,,,_)))rto o=o_.is. .gbogoe.&)rt.et.google.&)ntt)"eis.gaaegt.n_.n . .g.ogt("))nttaeis.ganett.rs.h;e_.j(a,,)));;.is.dd_..ogg==.0(_.j(a,,)));.is.dd_..ogg===.._s. .g=ogoe.&)rm.ot.google.&)n".")a.r""b."urnar rt.brntot"&)n_.b&b).j(a)))))).&;&."(".is.ddaa.ogn=_.0(_.j(a,,)));&&&&.i(_.s(,,,)));.is.dd_..ogg=..0(_.j(a,,)));;.is.od_..ogg=..0(_.j(a,,)));;.is.od_..ogg==.0(_.j(a,,)));;&(=.is.dd_..ogg=.=h_(_.z(a.,_.,);_)|r cd=fu,nctrnpe.ro_.rerneepeertre_arcoeypeeent()rnrorupeo perioe("tt"ois t.eisrn ee"aitenyge,oasettt0"rnltt"s""".ulsca,"c,,,,,0,0,0,0,0,,,,,24,,,,,4,,0,,,,,,,244,,448,,94,9448,284,,,298,7448,294,,,28428448,74lunction(a,b,{,{,{,{,{rarcall(this.h,0,},._de_.rs.h);....is 0=_.=thh,,(_.j(a,,)));.is..d(_.j(,,,)));;isrn a .h.io==d.__(t_))))&((_.aa(_)a,)).d).&((_.b(())b,)).i))))&).isrnara.b(_.))))e(_.r_)b,)|is.daaa.og===.0d=tr.r((e=g.a.(e))0e(tc==_)i,).is.data.s.i=.h;e=tc=;fth;1.c.ssc);n]]].(ctar d=0n t.i))).&e(eth)))=d.(e=gd))..."a(t(g,(f)),).&e(t(gd_)..."e(t(gb(f)=]n],=.(]]((gt=)))..(_..&))his.daaa.og==.h._(._....=.o_.,_).r cd=f.nction(a,{re(cri f c)&atturn a.aa(urn"uc,""."...")).iurn"e),"""""".")|
# .ncunction(a,{re(!.=ngars.u(d r(tar d=0.,=(.nc[lgth;c++){vic nb]l]]],=rs rn a}=(aun._.=aunctiepsf==function(a,{rets.h=_.v(a)};_.z(_.o_.r);).r cd=function(a{retub=_.is.i](g,i];ghis.h=n];his.h=n];his.h=nh}(ishhd(s.h))).i)))..i))(.is.d=_...__.hd(_.)))).d))).(.is.n.i].h;))).i .w=_.}(_.g(a,,)));&.i.is.h=t.;s.;=_.h(_.j(,,})));&.t.is.o=t.;..._(_.j(a,,)))&&&.oi..=..(_.j(a,,)))&&&.i_..=..(_.j(a,,)))&&&.i_..(._s.daa.._.if.ototype.ba=f=unction(a){){reisrn aa(a)i,his.h=t.is.h={hit r=;.isr=(ghis.h)))his ri""tnettern"t"t"t",ris.gaa){eascgaa)}).td(s.hd(t  ot"){r.ro.rd=function(a,{rets.h=tthhhis.i==hit.f;;his.i=ng;h_.zd=frototype.ba=fufunction(),{){){vers.h=_;tthv.i r=if.i)};;;..is.is,t)i.pd=frototype.ba=f=eu=function(a){re(!urs 0===this.i=te;oidta==tthis.i={;tsrng.ooo(";;);.ois.i=tgh;hishis,thi.pd=frototype.b==fufufunction(a){ret!urs 0===this.i=te;oidta==tthis.i={;tsrng.ooo(";;);.ois.i=a.}hishis,thi.r dd=function(a,{re(!.b)&atent(h)).is f==.is.f;==a.&a(a.ne(b 0;==a.&a(e(c,i(t.e(funffe(.n(=.n](.(.c(=].).(eod .(f.adf,a)as.h(e){_.tcnfeet;ncti".);;erdd.j.(frototype.t==unction(a){rf(.ca=a.{ene(t,i))eis.hai)hi.pd=frototype.b==unction(a){rf(.ca.aa{enl(t,i))eis.h,)e;.r dd=function(a,{){){vers.h=a.v(is.h=nh}his.h=nht_.id=function(a,{rei b=_.bas.h(".ie()).ce(ern ceeteere!._)erurn a.;a(tune(eg=b.(urn a.;a(aunc.lb=function(a{retu.h=_.th_.}d(s.is.h={hnu_.;d;this.h==e;h_.id;this.h==e;h_.id;this.h=ne;h_.id;this.o=nutt_.1d;this.h=nhtt_.;d;this.o=nh;t_.id;this.o=nh;h_.id;tr.md=.nd=frototype.t==.=do_unction(){return this.i.n_.w.=d=function(a{return this.i.n_.l.=d=function(a{return this.i.n_.l.=d=function(a{return this.i.;_.l.=d=function(a{return this.i.;_.l.=d=function(a{return this.i.n_.w.=d=function(a{return this.i.n_.l.=d=function(a{return this.i.n_.l.=funfnction(){return thi((_.id(frr.r cd=function(a,{rets.h=_.v(a)};_.z(_.o_.r);).rd=function(a{return thw((.s(a_.rm));_.pa=function(a{return _.a((.s(a_.));)))._.r fd=funs. .d.oa.n_;b_u. ."=oa.tt.rctio&.nt.is.t.dbog.at.nctio)))|tyrc.rs.b..cbanun e=of.,_.,_ cd=f.,f.,m.,b=.,d,_.om))|(eo _=o_.nd=f)|reo _=o_.nd=punte.;_.ns.n((f,|reo _=aa.ns.nd(f,|reo _=a..c.nf.nd=.sd,_.o_))|reo r=o_.n _d(f.nd=..ad.h";r.peicettion(e{}.ction(a){ret.is.0(=s.itt)id;rcyrc a.rati".&e)}.&a(uun(e.n_.bb(_))mb(tunction(a{retu.h=_.ithis.h={hit_.zd==.nction(a,{){rer d=a.ceas.i))at".i)tt.ie)ersc=));]n],a&.rtr ".r r=(f.b,erurn es.n]n]]n.(g)i]&e(]]],=etar d=0.b=(.cength;1++++])){bi]n]b&){,a,{))tur  a.aasane;c.aa=fununction(a{return a.aa(_ub((trr.c(=function(a{re(..call(this.hhi.p(_.,d,_.r);;bar cd=function(a{re(..call(this.hhi.p(_.o_.r);_b.ad=fbarcc),)...(_..ma=_rototype.b==fuqd.prototype.ba=_ufund...a_utd,d._d._rrma__rototype.b==_.qd.prototype.ba=_.nd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd.prototype.bh=_.nd.prototype.b==_.qd.prototype.b==_.nd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd.prototype.b==_.qd...__.fd,d._d._ro)...i rd=f.nef.n_.,t,t.).ond.a,.oi".|t"..rsc==a.n((f)|reo _=a..cu;s. .d.oa(ee.ca_.s(a,,t)))).t((",.o_&|".())h(_t.h(e){_._dumpexception(e)}
# tryi
# _.ra=function(a){retu.h=_.v(a)};_.z(_.,d,_.r);)}b_.ccte){_._dumpexception(e)}
# tryi
# _ar c==function(a){rets.h=_.v(a)};_.z(_.o_.r);).r cd=function(a{re(..all(this.t;his.h=tg}hhis.i==g;;_.zd_do_.,);..rfrototype.ba=unction(a){){rets.h=_;tthhhis.h.etee.na=toteefeoc.r.nfuntotype.t==_u=unction(),{){){ver .hoi=nttthis.r c==.n . .g.oa.ectiid.b==.ne_.jd,.;));;.ist=);&(_.d)))));.i.stt.r(_.j(,,,)));&..i(=_..(_.j(,,,)));;i(_.g(_.0(,,))));.i(_..(.((,,,)))&&.i.s(_,0,))&&.is.id_..tot._d.t(_,})))&&.i.s(a,,,))&&.is.i._..tot._d.t(d,)tsrsdrs.0)__.._()()is.da_.;s.h,;.is.n a.is.i_.r f==fun((.fd,_.,))_)))..t_.i_)or d==f.,((.f(,_.)));))|rro r=;..c.lg.n _.r_.,g.n f.;_.,g.;tt=.,].,_.,_);md=fd.r_.|("|r.batch(e){_._dumpexception(e)}
# tr{ryis.gaaattt;g/ba.asee""=tt_"""etuet "ooreesfonlet"trmret tl """r"rr""""aa>raott  gote,gb_dd .oarctrabc;tapx 2obtoeoreaooioedtusenthllegr_ts:0;0;-gbotkit-boan-tdeatgb_ia{.agbbkitt:::}.gbpb_kitt::0}.;gisegr-edtgb_id{.pgb_kitt:::}.gbpb_kitt::0}.;.gb_va{oororr::one}}esd-::0877f4}border::onourg;gb_tareaoht:goxe;red-iy::none};osthion:aoditsve;.ogt-nlegr:tente;;;edt-nliga:toon:none;;ost-nldgh:otn:goathin;egteith:1oith::one}.;-bez-boadsselect:tone;;meb-oet-select:tene;;mebkit-boatsfelect:tene;-gbb_va .over{.over{.ggb_la{goves{vover{ ackground-color:#gba(25,,0,222)}.)oony#:nppppsegt:onpp;.rpt:n00};tgton:ao_eee;ggleith0px;ki:t00%}.gbb_3a .over{.ggb_aa.gb_es{apckrngboration:none}rgbb_ba goveve{background-color:#gba(25,,244,25),.08)}ogrrnecoaation:none}.gbb_ba.oorkground:color:#g863f4;border#f8f;.gbb_ka.bovuve{background-color:#g063f4}.gb_ta.oarolradow:0o1px 0px 1pba(600,0,.15);.gb_za..gb_vd.gbb_dd.ggb_vd.oasplry:inleee-boock;-edthseight:40px;godting:00ppxx;.or--r-rodius:50x;.gb_ba.baskground:cf8f7fa}border-rox solid #48f3f6}.gb_ta.oaskground:cf8f7fa}.gb_t .ggb_bbgb_la.gb_jd .gb_dd.oalpr:#fff7f4}.or:dexoer:e}b_tinesgaation:none}.gb_.bgb_za.ooror:y:ofo}rgt}bgt-necgration:none}.gb_.d.bororr::ox solid #4863f4}boroirodoht:0oxe}wod-in::none};oscground:-ff77fa;bolkground:-febkit-boxdsett(0}aeht;ge_n:0eboce_nctoaoot:foocetell{gez-s:teith04077f4;c4ebkpp6666);bbectground:cfebkit-bodndr-grdnsett(0eat}458666;#486666)}bblkground:coattnego_dsettt0oat}4577f6;#b86666)}bbltirtpertte-.ongriigngne:gt-:gedth::oo:gb_ts tttteanhotrm:rrrtg0877fe;celodeor(::rac887fa)colcoett::::..o8egb_agbb_aa.horpr:#ffc;.gb_t .gb_er{backlradow:0 1px 0prgba(0,0,0,.15);.gb_za..bveve{backlradow:0ode: 0 1px 0 rgba(0,0,0,.15);box-hgound:cf88368;coldground:cfobkit-boxdsetr(1}coht-sedn:0ebnce_nctoaoo :fooceteli{gez-s:teitt04077d8}#8ebk2bx666);;;)ctground:cfebkit-bodndr-grdnsett(0eat}4586.};#486666)};;ckground:coaotnego_dsettt0oat}4576d}}#486666)};;ctrrtdeitte-ooxgriigngne:gt-:godth::on:gb_tr tttteathonrm:;ertg0877d8}celclittr:::ac88;d8).blgier:::::...2xgb_ngb_aa aarkground:#fff;forder:1px solid #48f6f}}bordrr#188768}coloir::nole;e-boock;tedtineigraoion:none}.gb_..b_aa{gover{background-cf8f7ff}boldrr-1olor:#g8ccf}}bordrr#1867f6}.gb ggb_aa.gbves{background-cf8f7fa;bolder#1867f6}ooloine:npx solid #406666}ogb_tgb_aa.gbveve{.gb_agb_aa.goves-aovive{oackground:cf8f;f8;color:#1867f6}ogb_tgb_aa.gb_j: ackground:#obn((arent;-oxder-oox solid #486668}.oolr:#4877f8;cogkineeg.aoion:none}.gb_.gb_aa.gb_j{ bver{background-coba(255,244,255,.08)}.oogr:#c8fafd}.gb_.gb_aa.gb_j:gbvus{background-coba(255,2,4,255,.08)}.oogr:#c8fafd}coloine:npx solid #48faf6}.gb_.gb_aa.gb_j:gbcive{.gb_tgb_aa.gb_j:govus,.ovive{background:coba(25,,2,4,255,.08)}.oor:#08fafd}.gb_t .asplry:nole;0oaoit:benegb_d{{oosiin-i:::godt:n:.gb_b .asol:y:inliee-boock;redti--l-goiin:niddle;;gb_ta{ggb_d{{asol:y:ofx;.irti:g0px;.gb_n .aro:yon:aodetive;.gb_ma.asol:y:inliee-boock;-eitii:nnone;;ogti--l-goiin:middle;;osger:rodius:50x;.moz-box-shai:g:border-box;bor-shai:t:border-box;bordit:4opx;podti:30px;.otg-r::onnte;;;edt-neiga:tion:none;;gb_tbggb_b_la oror:yyointtg.geat-deegration:none}.gb_.d.b_b_m{ aror:#fff}e}b_na{oarprr::olor:#ebnt:grent;-oxder:1olor::golor:#gbb;border-rodiui-exder-boloct 0ofoetmonder-godth:000p;.o;2oppx;.irgory:none;mostiion:aodilr;;;weith:0pppx;gidth2px;.igietx:100;;-it:40px;ti:n0p%e;kit-box--rton:gb_ka{..b,a._t-tton:ab_li .25;.gb_n .oarolr::olor:#ebnt:arent;-oxder:rolisi-exoe;-moloct gofoe mondei-godth:000p}.o;2oppx;.irgory:none;mostiion:aodilr;;;weith:0pppx;gidiexx:000;;-it:40px;ti:n00%egkit-box--rton:gb_ka{.gb,a._t-tton:ab_li .25;;.itar-radir::1olor:#bba(045,0,.2));ogtga0x;-gnbebbat fotaaecoge_da{oardrr:0olor::golot:#g8c;.gb_n..ackground:cf8f;fo;der::px solid #48f6f8;oor::olor::eda(2,5,.,22)).ootr:#f857e-egkit-box-shadow:0 1px 3prgbagba(0,0,0,.3);-moz-box-shadow:0 1px 3prgbagba(0,0,0,.3);-ox-shadow:0 1px 3prgbagba(0,0,0,.3);-ox-s:::none;moltit::noieimeith-n::aedte .godt-ion:aodilr;;;wegth::ox;podth2px;.webkit-box--rt-n ...
# tryi
# _.ra=function(a{ret!..)a).s((e)teitton(rt((_.luct.dreincttoptrty(_elurn c}}.iur==0bb.t.tu.h.drtenettoptrtyecali.b_urt pt"u_.ctanction(a{re(0).r{.a(ten  a==.nction(a{rer c==.nfpecttitton(ret,entrna.)e{c.&elertrn)ercte:(een(r(",enurna.)e{easch(e){r.ro on a};_...b=tch(e){_._dumpexception(e)}
# tryi
# _ar c==functinte)rerorn ectorn_)gbtceggbeec),b.ts.nctente)rerorn ector(_bgb.ge)eec"gb.(""bb(""b"e(f.bb("r,f)bnc"e";=&.atcc(e){_._dumpexception(e)}
# tryi
# _.ra=function(a,{ret b=_..cbaa;=t.nctain t)i))]&]ef.(]]]e(urn a};_.= f==function(a,{re(ccall(this.h,his.h==;}his.h=nh;t;this.h=nh;t.is.h==eit.is.h=ne;t.is.h=nhtttt_.hhiho_.nd;..;d=r.nction(a,{re(!.ia{risrn a.aa(unctir c=0n t.i))eng))))].]e(g))..c.)]n],())).iurn a}}a(ancunsrn a.ist(".rs.oootype.ta=unction(a){retu.h=tht(h};.;;a.is.i);...._.st.))hm.....((t   a)t.n],a)))a.._.r .ototype.ta=function(a){rets.h=_.t(hithi c=0ntt.is.h));;t.h)i];hhis)hd.is.t)t].hhis.hd(.pd=function(a){){rfr.cacang)br.rc pdrototype.ta=function(a){return t.a((_.is.taneis.h=n]hhhis.ii.o g==fun _.is.bb(f,hmd.f...")|n"))|_sch(e){_._dumpexception(e)}
# tryi
# _.ra=function(a,{){return a.aa(.s(.)));_..rtch(e){_._dumpexception(e)}
# tryi
# _ar c==functinte)rerorn ectorn_.bbtc.ggbtec),b.ts.rctente)rrrorneeetor(_bgb.ge)eea"gb.(""bb(""b"e(f.bb("rot)bnc"e")tttp.cc(e){_._dumpexception(e)}
# tr{ryis g=aattt;g/ba.asee""=m__""tetuen "o0rnt>"drnt>srr-e>ooaoey=="tttsc""onlentp""omtettl""""rye_"dete >oogoey===tttsc  ru-l""ontettp""ttps://ooa.ggtgli..com/s/lgee//odgse//ggroeoipu03rmrztueq0000r03009.gbel,"drl-u0rnlseype"ttml,"unte:tp""ttps://orive.google.com/,ilee//1lqzexepkaltybxnxxxbctpverrrtrij1/viewuuup%"dplegmg0rapkipi,dhpwhgtrrrrjrrrr0"aep  qonptin"""ttttsuupe""onteetp""ttps://drive.google.com/,ilee//1lqzexepkaltybxnxxxbctpverrrtrij1/vieeuunpaoeaddegaagarrjljirrr0"hele,ialonmc"nype"rrr00rt09)le"orlet 0oaeet"2rntttr-ror>oooddorrgod>oits groad morregra_hhmryl_.unction(a){vet b=ntct=aurs.t]}ntogar c==fuot.nd=function(a,{rei b=_.ce(lth"e.n&)b.&a=urnar r=;.nctiprod=a.d=(.n]+)f=r.=].(]=]b(urn a};ation a)e_.nfunction(a,{return a.r_.=a=function(a,{ret b=_.ieof=aa&a(artr " eot(ee.of,=nctara=fteotettt.)rturn a};enerr uaa=ateoteett.)){rarc eateinleis)nnteateert dans.ncteoteert ryeeor rbis.h(e){r._d,)otteype;a".)rsttrne)urcti".aesorn.e)r=r rn a};_.=b=function(a,{,{)eturn a.a:.pa(urn e:r nd.)bfb_.ca=function(a,{return _.r::(ur.bbb==.(urna0a_.p(=function(a{retu.0==.yyps.==(a.na(f)|rsc=(e!arcti)&_.purn a}i r.(ernar r=(ecfbnf.t(ee.t(eintd={)..b.iurt ers"_""tnnotsch(e){r.t pr=funt.pr=function(a,{rets.h=_.v(is.h==g};h_.z(=frototype.ba=function(a{return this.i.n_.l.=fuototype.ba=trrn==function(a{return this.i.thitri te)};_.pd=funtt.n.(f._.."e)_.b)b("un .n(b}..+"""."()a",""."e=s.g)\\\]]]]]],""_.\b=s.= ee(t;.n]&e=l==0==(=tur],==="("""."]]]]]]=&"|",|","\."]]]]]]=&|"|=,"\""\\"]]]]]]=&"\\"(|lue],=""""".","",",)(e=s.ect)bn]]a=](e;npe.t.ne=h;orsegaogrecreri:ernlaeateittgbatoettttatertrrrte:rrrrteitsgoagoettleaaesstrramogzmmigbdthemmrlsegrrrlertter1pi;eenygosaoaeesperns0as1s000,0009lal"ug,"b""]]]]],",)])))|"))|isr=(a.;c.;_.b(=function(a,{rets.h=_.v(is.h==g};;_.z(=fuototype.ba=function(a{return this.i.thisri te)};_.pd=fuototype.b==trrn==function(a{return this.i.thitri te)};_.pd=function(a){return _.a((trnceof _.gen&,.&bnetrcee.ro=.b.fb=a.ne=fbrrodrrottdersct re"ar.nb=function(a){ret b=_.ce(s);.a.(]+erateose:nl}{}tt.i rn a.i _.(.(f,b))))_.p==fun t.b.(f.b,).rtorneeor(e_==t.pentot"eooot.e.ototyteerr&.bbng))&b(c.nb(",b.(c""b."ue==func(function(a,{rei b=_0,_.t.r rn a.rction(){te(rnar]{,b.t.))..iurn a};at.rction(a=ter f==.nctrnto))egteote:t"te""rnc"ab.".nctento))eateote:ttt(""rnc""b."a=et feotttttnctento)aeateoteat"teaa.nc""b".0c=et feoittten){t.&bletn"coote.netentocte.)rnttr.n.lsb0bn".)b)c)brurn a}}a(urneeueert(eb.b(".bn.e".b+b)))]ea&b._.b&b"e((unction(a,{re(caurt b(f=rcuento)erurn a}}a(eorn ectorn(a.b.&b(coen eetor(_.bnetg"unttt.))ntet.rsf0enteg"oltt,rneneofoo0==&aa".=antthoontbncterortorn"};nco""t&__.""oisena0a=a0""""._.ca=function(a,{,{)etu.h=athtth}his.h=nghhh;.ic.pd=.nd=frototype.t.=.=dottooctiontenction(a{return this.i.nt.it.is.h,nthh;;;.r.=.=f.nction(a{return thhis.i=nt.tthis.h,nthh;;ri.pd=.o_th,nction(a{retu.h=tthtthih.shih(hhis.hhithhthhis.h=nghhh;eth.thnh(hhis.hhnthhh))his.n this.t_._h=hottefunction(a{retu.h=tthtthih.shittt).is.hhishhthhis.h=nghhh;etu.dhntttt.is.hhnhhhh;hhisrn this.t_._h=hototfunction(a{retu.h=tthtthih.shisotthis.h=nshh)hhis.h=nghhh;htu.this(tthis.h=nghhh;hhisrn this.t_._h=.nction(a,{){rei b=a.ncy onotetaen&){eter derterneestinnsl(&,a.&enetteerterytessennsl(&,{,fb&b(ct pnor.rinloaeru0={.nct.ea.fb=totnpeotorn"e())bnenttrn ectorn_.bn.&enlteneeetorn_blgbbb.sb))a."a=))))),),))err d eoo on(a)trrrf oo_;=b(function(a,{,{){rer d=a.c]nct.e(fraa(torn ectorn_.(&)b&.ntorn ectorn_.b&b=ern a.aa(eorneeetorn(e())b&bb..sb)_a.(s.)))".(ert"en enyceseinnsl()(ir f==.nenltteeotenyte)rindsl(),{,eiurn a.rct."b=ftefuotttyte)le&e(",""...("))b=r f==enc.r(tar.(],=(.)];]])){brr d==.cd(a.en t(s0=nction"===ypeof a&&ettot";a&a(s.na=tot".aa"....&))).i.=)ba]&e().i(th;c++eturn c};at(on a};_.=b=function(a,{return _.aa(_unctento)){r_..aa=function(a,{,{)fr.itof a&&afaretictoatlaaisrt&.is..b..fb(ltrceooeyc}}}t.&a=lof eete(n)"..iurn a}}a(cteone:ttt(")}rt.cb=function(a,{re((var d=a.l]ne(gth;ceote..f.tern etote&){rt.pe=function(a,{return _.a::fa(to((eetufanrneof ...
# tryi
# _ar c==funb(function(a,{re(!.rl====&a=urn a.r.(a)breo "===typeof a&&atsca=".(urn aur..nct=)|ncti""==yypeof a&&aturn a}r_.=a=function(a,{){rer d=a.rcyiorototype.file".full(a,b_yenteot;b..turn a}rction(){tet f==.cellot")=.fa(e==.rctec.a);t(rntoot.e(urn a}}anetrfarsrt}}ett.j(=function(a,{,{)eturn a.aa(_.n(a,a)});_.p(=function(a,{rets.h=_.v(a)};_.z(_.,d,_.r);).r cd=function(a{re(..call(this.hhi.p(_.o_.r);;b.rd=function(a,{){)et!.i)at.i))ersrn a.}a(unc.is.n_.r r=(f.b)._.rfunf.=.(t.nction(a,{return _.is.n.irototype.ta=uneefooettnnbblc(),b)&b(s.).se+e(g.nc.r.ab(f.0==(".i.ce=function(a,{re(!.inatrnceof _.go(a.ntrn a.;.(abrsrt"===ypeof a&&a.aa=aana())b.(eo  a)&;.teib f==.nenc&a.(a,itorye r==.nur=(e_are=fuc(e){_._duncti"t.r.pe.a=o_.."b=eoryeoornri!tne=uunctento))eateote:ttt(")r",b.iirn .rcti)r_.e:(e){r._uns 0;=.yctif=a_.."b=toryto).n]bbba..(cvab...(]b(ct="t;r|pb.r ri"rotet}}aaa&a"aiab=(en"ar rirdfiguc  nyea;;.turn a}}a(aanb).ca=function(a,{return _.aa(_.ia(t.),}.}b_..rtch(e){_._dumpexception(e)}
# tryi
# _.bb__.ttegaat,t"e")rutttteet"0.ncte:"t====a"a"uba=funf.nc.nction(a,{return a.i _.b.(f.nction(a){return a.aa(tur g}}.".(urn"a.=..is.   ete((,"n..&a"".
# r_r= unc.p==function(a,{rets.h=_.t_.id=frototype.ba=trrn==function(a{return this.i.t}};_.p(=frototype.b==_.b_.pd=prototype.ba=function(a{return this.i.thisri te)};_.pd=function(a,{return _.aa(_.id.rsr   e);;_.pa=function(a,{return _.a((trnceof _.ge({.."e(etrceeoro=...fb=tunb=.boto=erotideoeot"ee)te(eneeat"e).sr=function(a,{ret b=_.ce(s)b.a.(]]erateo(eert r(ee}}
# }&ei rn a.is_."b(f.bb(f)r.cb=fuunction"==tyypeof b?neoa&b=function(a,{rets.h=tthh_.=.=funcf.bne""db.(""|nct"a&e_""r(ctr"t&a"""r("ct"";"."""rnc"are"ura=a=fuoction(a){return a.r:fu0f=".0(|
# .b_.(urna0e_.s(barch(e){_._dumpexception(e)}
# tryi
# _.ra=function(a,{rets.h=_.v(a)};_.z(_.,d,_.r);)}b_tcc(e){_._dumpexception(e)}
# tryi
# _.ra=function(a,{){){vfr.it==da{b(t.a);tr   eto(()"_.rergeen"t)=t"."attofb&ets.idc.t.=e(g)b)(eo on"ton(e))."etet on"tenee&aeetetolilla)""a"a=ur ee "or("".nct"")ttca."a(etf)&rttonceof _.go(e.ne(".b,.&netrnceof _.ge(e.nb(frb,.&b(_.))())))._.batch(e){_._dumpexception(e)}
# tryi
# _.ra=function(a,{ret b=_.c,aeis f.&==..a..)a(rn on"tenee&).netro on"tenee&angtetolileornye(o(babnctento);tntorn ectorn_bnaei0,nntaae(aab)bauct"ntot!t"),=t.taca.ellth.en!tncternglorn0}onco""t|t_.b""__a."aturtee "er("".nl"""tttc_.na=function(a,{,{)eturn a.rat.rron e)}.nurt".nterneel"e:e("riro ""){}oa.batch(e){_._dumpexception(e)}
# tryi
# _ar c==function(a,{){){vfr.n](c=i,bb&b)&a(s.nc!)rcti";;n.&,b&d=a,b&)errn arc.===function(a,{,{)e(!.ll)rs d==.0e(g)|rurn")==tpc(at="&&=.pa(eo=&|n.rnaruroeertegaa&aneurn a)tnto.&=.fa=e"a"b=f.nc..)b(_.b).&e(t(rn e.ra(_.n_.b)).,.(t_..cc(_..r""))=...(.etiono ott))rer.rcunction(a,{rets.h=_.v(a)};_.z(_.o_.r);).r cd=fund=.=d,_.o_)))b(eo o=o_.._.;_.hn".nd=.o_.)),p)))..]((_.)())l_.)|(_)|..(e,=)r_);_..("un(=.=_.)))p)))..d((_.j())l_.)|(_)|..(e,=.ra.nction(a{re(!.b)).a(s.ig)er d==.0e(_)|ree))&.&c=er rnetere!)bneo""&r_.rnaratab."e=".j((f)bree"ree"t)=t.puf==.ne(g)b.&(=a.(ur eer or(",.nct""tttc.&c(").r""))=t..((etionttttt)}rer..(ction(a)ter b==.0e());.(".i)),f,)&)=(_)).((eirn r==.0d(a)a,)).(r..(t. .b=aa.e;ttiry:e.rt0,.nc""=bnction(a{tetu.noirttettee((_arc)bb)rrt.b."b(tch(e){_._dumpexception(e)}
# tr{ryis g=aattt;g/ba.asee""om__""tetuen "oortet "on"ca=er"ar""bncyi/trle="tt.etate.eeirlr>"oll""rtls://drw.ggtgli..com/s/docs-eull,e..cbodolfonupe-eoresey/rgodiokiqq0obbpe_adraaqqqbr>ooq2d0rpser>"duo"oasotrjaoraooon"""rmsfi="donte""2rnteep-"or"oeeddorraod>"htbtuen "oorrleggdrlle
